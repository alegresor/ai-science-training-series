# %%
import pandas as pd
import matplotlib
# %matplotlib inline

# %%
df = pd.read_csv('output.txt')
print('iterations: %d'%len(df))
df.head()
# Out:
# iterations: 5004
#       loss  accuracy
# 0  132.284       0.0
# 1   76.449       0.0
# 2   33.022       0.0
# 3   20.330       0.0
# 4   12.935       0.0

# %%
fig,ax = matplotlib.pyplot.subplots(nrows=1,ncols=2,figsize=(8,4))
ax[0].plot(df['loss'])
ax[0].set_title('log10(loss) vs log(iteration)')
ax[0].set_yscale('log',base=10)
ax[0].set_xscale('log',base=10)
ax[1].plot(df['accuracy'])
ax[1].set_title('accuracy vs iteration');

# %% [markdown]
# I modified the `train_resnet34.py` file to ouptut loss and accuracy to an output file in pandas-compatible format
